# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading Dataset

# %%
# from google.colab import files
 
 
# uploaded = files.upload()

# %%
AMZN_df = pd.read_csv('AMZN.csv', parse_dates = ['Date'], index_col = 0)
FB_df = pd.read_csv('FB.csv', parse_dates = ['Date'], index_col = 0)
netflix_df = pd.read_csv('netflix.csv', parse_dates = ['Date'], index_col = 0)

# %%
print(AMZN_df.shape)
print(FB_df.shape)
print(netflix_df.shape)
# Out:
# (1257, 6)
# (1257, 6)
# (1257, 6)

# %%
AMZN_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-02  312.579987  314.750000  306.959991  308.519989  308.519989
# 2015-01-05  307.010010  308.380005  300.850006  302.190002  302.190002
# 2015-01-06  302.239990  303.000000  292.380005  295.290009  295.290009
# 2015-01-07  297.500000  301.279999  295.329987  298.420013  298.420013
# 2015-01-08  300.320007  303.140015  296.109985  300.459991  300.459991
#
#              Volume
# Date
# 2015-01-02  2783200
# 2015-01-05  2774200
# 2015-01-06  3519000
# 2015-01-07  2640300
# 2015-01-08  3088400

# %%
FB_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  78.580002  78.930000  77.699997  78.449997  78.449997  18177500
# 2015-01-05  77.980003  79.250000  76.860001  77.190002  77.190002  26452200
# 2015-01-06  77.230003  77.589996  75.360001  76.150002  76.150002  27399300
# 2015-01-07  76.760002  77.360001  75.820000  76.150002  76.150002  22045300
# 2015-01-08  76.739998  78.230003  76.080002  78.180000  78.180000  23961000

# %%
netflix_df = netflix_df.iloc[:, [2,0,1,3,4,5]]
netflix_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  49.151428  50.331429  48.731430  49.848572  49.848572  13475000
# 2015-01-05  49.258572  49.258572  47.147144  47.311428  47.311428  18165000
# 2015-01-06  47.347141  47.639999  45.661430  46.501431  46.501431  16037700
# 2015-01-07  47.347141  47.421429  46.271427  46.742859  46.742859   9849700
# 2015-01-08  47.119999  47.835712  46.478573  47.779999  47.779999   9601900

# %%
AMZN_df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-23  1788.260010  1793.000000  1784.510010  1793.000000  1793.000000
# 2019-12-24  1793.810059  1795.569946  1787.579956  1789.209961  1789.209961
# 2019-12-26  1801.010010  1870.459961  1799.500000  1868.770020  1868.770020
# 2019-12-27  1882.920044  1901.400024  1866.010010  1869.800049  1869.800049
# 2019-12-30  1874.000000  1884.000000  1840.619995  1846.890015  1846.890015
#
#              Volume
# Date
# 2019-12-23  2136400
# 2019-12-24   881300
# 2019-12-26  6005400
# 2019-12-27  6186600
# 2019-12-30  3674700

# %%
FB_df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-12-23  206.699997  208.589996  205.679993  206.179993  206.179993
# 2019-12-24  206.300003  206.789993  205.000000  205.119995  205.119995
# 2019-12-26  205.570007  207.820007  205.309998  207.789993  207.789993
# 2019-12-27  208.669998  208.929993  206.589996  208.100006  208.100006
# 2019-12-30  207.860001  207.899994  203.899994  204.410004  204.410004
#
#               Volume
# Date
# 2019-12-23  13348900
# 2019-12-24   6046300
# 2019-12-26   9350700
# 2019-12-27  10284200
# 2019-12-30  10524300

# %%
netflix_df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-12-23  337.760010  337.950012  331.019989  333.100006  333.100006
# 2019-12-24  334.010010  335.700012  331.600006  333.200012  333.200012
# 2019-12-26  334.600006  336.459992  332.010010  332.630005  332.630005
# 2019-12-27  332.959992  333.820007  326.010010  329.089996  329.089996
# 2019-12-30  329.079987  329.190002  322.859985  323.309998  323.309998
#
#              Volume
# Date
# 2019-12-23  5765300
# 2019-12-24  2019300
# 2019-12-26  3589900
# 2019-12-27  5036100
# 2019-12-30  4311500

# %%
print(AMZN_df.info())
print()
print(FB_df.info())
print()
print(netflix_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2015-01-02 to 2019-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1257 non-null   float64
#  1   High       1257 non-null   float64
#  2   Low        1257 non-null   float64
#  3   Close      1257 non-null   float64
#  4   Adj Close  1257 non-null   float64
#  5   Volume     1257 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.7 KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2015-01-02 to 2019-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1257 non-null   float64
#  1   High       1257 non-null   float64
#  2   Low        1257 non-null   float64
#  3   Close      1257 non-null   float64
#  4   Adj Close  1257 non-null   float64
#  5   Volume     1257 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.7 KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2015-01-02 to 2019-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1257 non-null   float64
#  1   High       1257 non-null   float64
#  2   Low        1257 non-null   float64
#  3   Close      1257 non-null   float64
#  4   Adj Close  1257 non-null   float64
#  5   Volume     1257 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.7 KB
# None

# %%
# Checking for Null Values
print(AMZN_df.isnull().values.sum())
print()
print(FB_df.isnull().values.sum())
print()
print(netflix_df.isnull().values.sum())
# Out:
# 0
#
# 0
#
# 0

# %%
# Check if at least one element is 0.
print(AMZN_df.eq(0).any().any())
print(FB_df.eq(0).any().any())
print(netflix_df.eq(0).any().any())
# Out:
# False
# False
# False

# %%
# Two columns 'Close' and 'Adj Close' are equal, so we drop the Adj Close column.
print(sum(AMZN_df['Close'] - AMZN_df['Adj Close']))
print(sum(FB_df['Close'] - FB_df['Adj Close']))
print(sum(netflix_df['Close'] - netflix_df['Adj Close']))
# Out:
# 0.0
# 0.0
# 0.0

# %%
AMZN_df.drop('Adj Close' , inplace = True , axis = 1)
FB_df.drop('Adj Close' , inplace = True , axis = 1)
netflix_df.drop('Adj Close' , inplace = True , axis = 1)

# %%
print(AMZN_df.head())
print()
print(FB_df.head())
print()
print(netflix_df.head())
# Out:
#                   Open        High         Low       Close   Volume
# Date
# 2015-01-02  312.579987  314.750000  306.959991  308.519989  2783200
# 2015-01-05  307.010010  308.380005  300.850006  302.190002  2774200
# 2015-01-06  302.239990  303.000000  292.380005  295.290009  3519000
# 2015-01-07  297.500000  301.279999  295.329987  298.420013  2640300
# 2015-01-08  300.320007  303.140015  296.109985  300.459991  3088400
#
#                  Open       High        Low      Close    Volume
# Date
# 2015-01-02  78.580002  78.930000  77.699997  78.449997  18177500
# 2015-01-05  77.980003  79.250000  76.860001  77.190002  26452200
# 2015-01-06  77.230003  77.589996  75.360001  76.150002  27399300
# 2015-01-07  76.760002  77.360001  75.820000  76.150002  22045300
# 2015-01-08  76.739998  78.230003  76.080002  78.180000  23961000
#
#                  Open       High        Low      Close    Volume
# Date
# 2015-01-02  49.151428  50.331429  48.731430  49.848572  13475000
# 2015-01-05  49.258572  49.258572  47.147144  47.311428  18165000
# 2015-01-06  47.347141  47.639999  45.661430  46.501431  16037700
# 2015-01-07  47.347141  47.421429  46.271427  46.742859   9849700
# 2015-01-08  47.119999  47.835712  46.478573  47.779999   9601900

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %% [markdown]
# ### **Make an Analysis on (Open, High, Low, Close)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Open stock prices
fig, ax = plt.subplots(figsize=(20,10))
sns.lineplot(data=AMZN_df['Open'],linewidth=1)
sns.lineplot(data=FB_df['Open'],linewidth=1)
sns.lineplot(data=netflix_df['Open'],linewidth=1)
plt.legend(['Amazon', 'Facebook', 'Netflix'])
plt.title("'Open' stock prices from 2015 to 2020")
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
# High stock prices
fig, ax = plt.subplots(figsize=(20,10))
sns.lineplot(data=AMZN_df['High'],linewidth=1)
sns.lineplot(data=FB_df['High'],linewidth=1)
sns.lineplot(data=netflix_df['High'],linewidth=1)
plt.legend(['Amazon', 'Facebook', 'Netflix'])
plt.title("'High' stock prices from 2015 to 2020")
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
# Low stock prices
fig, ax = plt.subplots(figsize=(20,10))
sns.lineplot(data=AMZN_df['Low'],linewidth=1)
sns.lineplot(data=FB_df['Low'],linewidth=1)
sns.lineplot(data=netflix_df['Low'],linewidth=1)
plt.legend(['Amazon', 'Facebook', 'Netflix'])
plt.title("'Low' stock prices from 2015 to 2020")
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
# Close stock prices
fig, ax = plt.subplots(figsize=(20,10))
sns.lineplot(data=AMZN_df['Close'],linewidth=1)
sns.lineplot(data=FB_df['Close'],linewidth=1)
sns.lineplot(data=netflix_df['Close'],linewidth=1)
plt.legend(['Amazon', 'Facebook', 'Netflix'])
plt.title("'Close' stock prices from 2015 to 2020")
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ### **Make an Analysis on (Volumn)**

# %%
# Volume
fig, ax = plt.subplots(figsize=(20,10))
sns.lineplot(data=AMZN_df['Volume'],linewidth=1)
sns.lineplot(data=FB_df['Volume'],linewidth=1)
sns.lineplot(data=netflix_df['Volume'],linewidth=1)
plt.legend(['Amazon', 'Facebook', 'Netflix'])
plt.title("'Volume' from 2015 to 2020")
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ### **CORRELATION**

# %%
#Using Pearson Correlation
fig, axs = plt.subplots(ncols=3,figsize=(20,12))
for i in range(3):
  ax=axs[i]
  if i == 0:
    sns.heatmap(AMZN_df.corr(), annot=True, cmap = plt.cm.CMRmap_r, linecolor='white', linewidth=2, ax=ax)
    ax.title.set_text('Amazon feature correlation')
  if i == 1:
    sns.heatmap(FB_df.corr(), annot=True, cmap = plt.cm.CMRmap_r, linecolor='white', linewidth=2, ax=ax)
    ax.title.set_text('Facebook feature correlation')
  if i == 2:
    sns.heatmap(netflix_df.corr(), annot=True, cmap = plt.cm.CMRmap_r, linecolor='white', linewidth=2, ax=ax)
    ax.title.set_text('Netflix feature correlation')
plt.show()

# %% [markdown]
# **Feature Open, high, low are highly correlated to Target feature Close. we can use either one of the feature for prediction to avoid multicollinearity**

# %% [markdown]
# # Normalizing the Dataset

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# ## AMAZON

# %%
AMZN_close_stock = AMZN_df['Close']
# AMZN_close_stock.dropna(inplace=True)

AMZN_close_stock_scaled = sc.fit_transform(np.array(AMZN_close_stock).reshape(-1,1))
AMZN_close_stock_scaled
# Out:
# array([[0.0123077 ],
#        [0.00869584],
#        [0.00475875],
#        ...,
#        [0.90257681],
#        [0.90316454],
#        [0.89009221]])

# %%
AMZN_train_size = int(len(AMZN_close_stock_scaled)*0.65)
AMZN_test_size = len(AMZN_close_stock_scaled) - AMZN_train_size

AMZN_train_set, AMZN_test_set = AMZN_close_stock_scaled[0:AMZN_train_size, :], AMZN_close_stock_scaled[AMZN_train_size:len(AMZN_close_stock_scaled), :1]

# %% [markdown]
# # Create train, test data

# %%
def load_data(dataset, timesteps = 1):
  X = []
  y = []
  for i in range(timesteps, len(dataset)):
    X.append(dataset[i-timesteps:i, 0])
    y.append(dataset[i, 0])

  return np.array(X), np.array(y)
# # Reshaping
# X = np.reshape(X, (X.shape[0], X.shape[1], 4))
# # y=np.reshape(y,(y.shape[0],1))

# %%
timesteps = 100

AMAZON_x_train, AMAZON_y_train = load_data(AMZN_train_set,timesteps)
AMAZON_x_test, AMAZON_y_test = load_data(AMZN_test_set,timesteps)
# print(AMAZON_x_train)
print(AMAZON_x_train.shape)
# print(AMAZON_y_train)
print(AMAZON_y_train.shape)
# Out:
# (717, 100)
# (717,)

# %%
# Reshaping
AMAZON_x_train = np.reshape(AMAZON_x_train, (AMAZON_x_train.shape[0], AMAZON_x_train.shape[1], 1))
AMAZON_x_test = np.reshape(AMAZON_x_test, (AMAZON_x_test.shape[0], AMAZON_x_test.shape[1], 1))

# %% [markdown]
# # Model and validate data

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, SimpleRNN

# %%
def SimpleRNN_model_without_dropout(trainX, trainy):
  n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], 1
  input_shape=(n_timesteps,n_features)
  print (input_shape)
  model = Sequential()
  # Adding the first RNN layer
  model.add(SimpleRNN(units = 50, activation='tanh', return_sequences = True, input_shape = input_shape))
  
  # Adding a second RNN layer
  model.add(SimpleRNN(units = 50, return_sequences = True))

  # Adding a third LSTM layer 
  model.add(SimpleRNN(units = 50))

  # Adding the output layer
  model.add((Dense(n_outputs)))
  return model

# %%
def SimpleRNN_model_dropout(trainX, trainy):
  n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], 1
  input_shape=(n_timesteps,n_features)
  print (input_shape)
  model = Sequential()
  # Adding the first RNN layer and some Dropout regularisation
  model.add(SimpleRNN(units = 50, activation='tanh', return_sequences = True, input_shape = input_shape))
  model.add(Dropout(0.2))

  # Adding a second RNN layer and some Dropout regularisation
  model.add(SimpleRNN(units = 50, return_sequences = True))
  model.add(Dropout(0.2))

  # Adding a third LSTM layer and some Dropout regularisation
  model.add(SimpleRNN(units = 50))
  model.add(Dropout(0.2))
  # Adding the output layer
  model.add((Dense(n_outputs)))
  return model

# %% [markdown]
# ### **AMAZON**

# %% [markdown]
# ## RNN

# %% [markdown]
# #### **RNN without Regularization method**

# %%
AMAZON_model=SimpleRNN_model_without_dropout(AMAZON_x_train, AMAZON_y_train)
# Out:
# (100, 1)

# %%
AMAZON_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 100, 50)           2600
#
#  simple_rnn_1 (SimpleRNN)    (None, 100, 50)           5050
#
#  simple_rnn_2 (SimpleRNN)    (None, 50)                5050
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 12,751
# Trainable params: 12,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the RNN
AMAZON_model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
import datetime
begin_time = datetime.datetime.now()
epochs, batch_size = 100, 32
history=AMAZON_model.fit(AMAZON_x_train, AMAZON_y_train, shuffle=True, validation_split = 0.1, epochs=epochs, batch_size=batch_size, verbose=1)
print(datetime.datetime.now() - begin_time)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 4s 85ms/step - loss: 0.1138 - val_loss: 0.0396
# Epoch 2/100
# 21/21 [==============================] - 1s 66ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 3/100
# 21/21 [==============================] - 1s 64ms/step - loss: 8.8734e-04 - val_loss: 0.0020
# Epoch 4/100
# 21/21 [==============================] - 1s 66ms/step - loss: 4.5323e-04 - val_loss: 0.0013
# Epoch 5/100
# 21/21 [==============================] - 1s 64ms/step - loss: 3.8195e-04 - val_loss: 0.0011
# Epoch 6/100
# 21/21 [==============================] - 1s 67ms/step - loss: 3.6637e-04 - val_loss: 0.0011
# Epoch 7/100
# 21/21 [==============================] - 1s 66ms/step - loss: 3.6404e-04 - val_loss: 0.0012
# Epoch 8/100
# 21/21 [==============================] - 1s 65ms/step - loss: 3.1605e-04 - val_loss: 0.0012
# Epoch 9/100
# 21/21 [==============================] - 1s 64ms/step - loss: 3.1482e-04 - val_loss: 0.0012
# Epoch 10/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.9722e-04 - val_loss: 0.0011
# Epoch 11/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.7658e-04 - val_loss: 0.0012
# Epoch 12/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.7934e-04 - val_loss: 0.0015
# Epoch 13/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.7286e-04 - val_loss: 0.0014
# Epoch 14/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.6857e-04 - val_loss: 0.0011
# Epoch 15/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.7411e-04 - val_loss: 9.9550e-04
# Epoch 16/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.4008e-04 - val_loss: 0.0013
# Epoch 17/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.1909e-04 - val_loss: 0.0015
# Epoch 18/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.7913e-04 - val_loss: 8.9869e-04
# Epoch 19/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.1233e-04 - val_loss: 9.1704e-04
# Epoch 20/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.1935e-04 - val_loss: 9.7610e-04
# Epoch 21/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.9475e-04 - val_loss: 8.5817e-04
# Epoch 22/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.9693e-04 - val_loss: 8.8607e-04
# Epoch 23/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.9348e-04 - val_loss: 8.4704e-04
# Epoch 24/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.8588e-04 - val_loss: 8.8410e-04
# Epoch 25/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.8899e-04 - val_loss: 8.4577e-04
# Epoch 26/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.4235e-04 - val_loss: 9.9895e-04
# Epoch 27/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.4115e-04 - val_loss: 7.7520e-04
# Epoch 28/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.9976e-04 - val_loss: 8.5225e-04
# Epoch 29/100
# 21/21 [==============================] - 1s 67ms/step - loss: 1.8018e-04 - val_loss: 9.4348e-04
# Epoch 30/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.0865e-04 - val_loss: 7.3286e-04
# Epoch 31/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.9009e-04 - val_loss: 0.0012
# Epoch 32/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.3837e-04 - val_loss: 7.3254e-04
# Epoch 33/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.6325e-04 - val_loss: 7.6407e-04
# Epoch 34/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.8859e-04 - val_loss: 6.8745e-04
# Epoch 35/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.6944e-04 - val_loss: 6.7935e-04
# Epoch 36/100
# 21/21 [==============================] - 2s 116ms/step - loss: 2.3484e-04 - val_loss: 0.0015
# Epoch 37/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.4100e-04 - val_loss: 0.0011
# Epoch 38/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.0335e-04 - val_loss: 7.3471e-04
# Epoch 39/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.9503e-04 - val_loss: 8.9214e-04
# Epoch 40/100
# 21/21 [==============================] - 1s 63ms/step - loss: 2.0569e-04 - val_loss: 6.3541e-04
# Epoch 41/100
# 21/21 [==============================] - 1s 66ms/step - loss: 2.1913e-04 - val_loss: 7.6835e-04
# Epoch 42/100
# 21/21 [==============================] - 1s 63ms/step - loss: 1.6239e-04 - val_loss: 6.2524e-04
# Epoch 43/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.3790e-04 - val_loss: 6.4531e-04
# Epoch 44/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.9425e-04 - val_loss: 6.5556e-04
# Epoch 45/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.7127e-04 - val_loss: 5.7816e-04
# Epoch 46/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.7143e-04 - val_loss: 6.4276e-04
# Epoch 47/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.5302e-04 - val_loss: 7.1381e-04
# Epoch 48/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.4814e-04 - val_loss: 6.6037e-04
# Epoch 49/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.4490e-04 - val_loss: 6.3029e-04
# Epoch 50/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.1801e-04 - val_loss: 6.1948e-04
# Epoch 51/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.3905e-04 - val_loss: 5.9326e-04
# Epoch 52/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.9696e-04 - val_loss: 0.0011
# Epoch 53/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.0735e-04 - val_loss: 5.8673e-04
# Epoch 54/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.0212e-04 - val_loss: 5.6669e-04
# Epoch 55/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.5733e-04 - val_loss: 5.4628e-04
# Epoch 56/100
# 21/21 [==============================] - 1s 67ms/step - loss: 1.3113e-04 - val_loss: 6.6608e-04
# Epoch 57/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.6049e-04 - val_loss: 5.1887e-04
# Epoch 58/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.3121e-04 - val_loss: 6.3615e-04
# Epoch 59/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.8274e-04 - val_loss: 6.0752e-04
# Epoch 60/100
# 21/21 [==============================] - 1s 65ms/step - loss: 3.6134e-04 - val_loss: 6.3711e-04
# Epoch 61/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.4507e-04 - val_loss: 5.7606e-04
# Epoch 62/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.4609e-04 - val_loss: 5.5738e-04
# Epoch 63/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.1119e-04 - val_loss: 5.9619e-04
# Epoch 64/100
# 21/21 [==============================] - 1s 67ms/step - loss: 2.4460e-04 - val_loss: 4.9198e-04
# Epoch 65/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.4973e-04 - val_loss: 5.0443e-04
# Epoch 66/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.2834e-04 - val_loss: 7.1480e-04
# Epoch 67/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.3492e-04 - val_loss: 6.8984e-04
# Epoch 68/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.5949e-04 - val_loss: 7.3491e-04
# Epoch 69/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.6890e-04 - val_loss: 4.7337e-04
# Epoch 70/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.2113e-04 - val_loss: 4.7114e-04
# Epoch 71/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.0615e-04 - val_loss: 4.6842e-04
# Epoch 72/100
# 21/21 [==============================] - 1s 66ms/step - loss: 1.1375e-04 - val_loss: 4.6264e-04
# Epoch 73/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.2710e-04 - val_loss: 4.9673e-04
# Epoch 74/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.1442e-04 - val_loss: 4.8576e-04
# Epoch 75/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.4807e-04 - val_loss: 4.8475e-04
# Epoch 76/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.0611e-04 - val_loss: 9.5276e-04
# Epoch 77/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.8179e-04 - val_loss: 4.3710e-04
# Epoch 78/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.3870e-04 - val_loss: 4.5679e-04
# Epoch 79/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.4720e-04 - val_loss: 6.9256e-04
# Epoch 80/100
# 21/21 [==============================] - 1s 66ms/step - loss: 1.4162e-04 - val_loss: 4.2906e-04
# Epoch 81/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.0503e-04 - val_loss: 4.8098e-04
# Epoch 82/100
# 21/21 [==============================] - 1s 65ms/step - loss: 9.4349e-05 - val_loss: 4.9475e-04
# Epoch 83/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.0069e-04 - val_loss: 4.6091e-04
# Epoch 84/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.5451e-04 - val_loss: 9.0713e-04
# Epoch 85/100
# 21/21 [==============================] - 1s 64ms/step - loss: 2.1170e-04 - val_loss: 7.4778e-04
# Epoch 86/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.9135e-04 - val_loss: 4.2575e-04
# Epoch 87/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.3174e-04 - val_loss: 7.0204e-04
# Epoch 88/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.2956e-04 - val_loss: 4.4257e-04
# Epoch 89/100
# 21/21 [==============================] - 1s 66ms/step - loss: 1.2309e-04 - val_loss: 6.0367e-04
# Epoch 90/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.2918e-04 - val_loss: 4.3836e-04
# Epoch 91/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.2772e-04 - val_loss: 5.2837e-04
# Epoch 92/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.0477e-04 - val_loss: 4.1152e-04
# Epoch 93/100
# 21/21 [==============================] - 1s 66ms/step - loss: 1.4953e-04 - val_loss: 6.0400e-04
# Epoch 94/100
# 21/21 [==============================] - 1s 66ms/step - loss: 2.3746e-04 - val_loss: 5.2925e-04
# Epoch 95/100
# 21/21 [==============================] - 1s 66ms/step - loss: 1.4708e-04 - val_loss: 0.0013
# Epoch 96/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.9545e-04 - val_loss: 3.9552e-04
# Epoch 97/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.4343e-04 - val_loss: 0.0012
# Epoch 98/100
# 21/21 [==============================] - 1s 65ms/step - loss: 2.4883e-04 - val_loss: 3.8772e-04
# Epoch 99/100
# 21/21 [==============================] - 1s 64ms/step - loss: 1.3753e-04 - val_loss: 4.2618e-04
# Epoch 100/100
# 21/21 [==============================] - 1s 65ms/step - loss: 1.2827e-04 - val_loss: 5.5300e-04
# 0:02:20.230228

# %% [markdown]
# ##### **Do the prediction and check performance metrics**

# %%
# plot loss during training
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(AMAZON_model, show_shapes=True, show_layer_names=True)

# %%
begin_time = datetime.datetime.now()
train_pred = AMAZON_model.predict(AMAZON_x_train)
test_pred = AMAZON_model.predict(AMAZON_x_test)
print(datetime.datetime.now() - begin_time)
# Out:
# 23/23 [==============================] - 1s 17ms/step
# 11/11 [==============================] - 0s 17ms/step
# 0:00:01.365310

# %%
train_pred_inv = sc.inverse_transform(train_pred.copy())
test_pred_inv = sc.inverse_transform(test_pred.copy())
AMAZON_y_train_inv = sc.inverse_transform(np.reshape(AMAZON_y_train,(len(AMAZON_y_train),1)))
AMAZON_y_test_inv = sc.inverse_transform(np.reshape(AMAZON_y_test,(len(AMAZON_y_test),1)))

# %%
# evaluation metrics
mse = np.mean(((train_pred_inv - AMAZON_y_train_inv) ** 2))
print("MSE", mse)
print("RMSE", np.sqrt(mse))
# Out:
# MSE 547.277674657309
# RMSE 23.393966629396328

# %%
mse = np.mean(((test_pred_inv - AMAZON_y_test_inv) ** 2))
print("MSE", mse)
print("RMSE", np.sqrt(mse))
# Out:
# MSE 3571.4279576256304
# RMSE 59.76142533127561

# %%
from sklearn.metrics import accuracy_score
# print(test_pred)

for i in range(10):
    print(test_pred_inv[i], AMAZON_y_test_inv[i])
# Out:
# [1820.7675] [1902.900024]
# [1851.2808] [1905.390015]
# [1857.3799] [1927.680054]
# [1842.1543] [1932.819946]
# [1861.73] [1998.099976]
# [1895.0697] [2002.380005]
# [1899.4388] [2012.709961]
# [1905.467] [2039.51001]
# [1920.0386] [1994.819946]
# [1919.9221] [1958.310059]

# %%
plt.figure(figsize=(16,8))
plt.plot(AMAZON_y_test_inv, color = 'black', label = 'Test')
plt.plot(test_pred_inv, color = 'green', label = 'pred')
plt.title('SimpleRNN without DROPOUT REGULARIZATION')
plt.legend()
plt.show()

# %% [markdown]
# #### **RNN with Regularization method**

# %%
AMAZON_model_dropout=SimpleRNN_model_dropout(AMAZON_x_train, AMAZON_y_train)
# Out:
# (100, 1)

# %%
AMAZON_model_dropout.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 100, 50)           2600
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  simple_rnn_4 (SimpleRNN)    (None, 100, 50)           5050
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  simple_rnn_5 (SimpleRNN)    (None, 50)                5050
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 12,751
# Trainable params: 12,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the RNN
AMAZON_model_dropout.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
import datetime
begin_time = datetime.datetime.now()
epochs, batch_size = 100, 32
history=AMAZON_model_dropout.fit(AMAZON_x_train, AMAZON_y_train, shuffle=True, validation_split = 0.1, epochs=epochs, batch_size=batch_size, verbose=1)
print(datetime.datetime.now() - begin_time)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 4s 89ms/step - loss: 0.2266 - val_loss: 0.0370
# Epoch 2/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0962 - val_loss: 0.0149
# Epoch 3/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0638 - val_loss: 0.0205
# Epoch 4/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0457 - val_loss: 0.0272
# Epoch 5/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0315 - val_loss: 0.0019
# Epoch 6/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0261 - val_loss: 0.0170
# Epoch 7/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0221 - val_loss: 0.0060
# Epoch 8/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0173 - val_loss: 0.0038
# Epoch 9/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0145 - val_loss: 0.0052
# Epoch 10/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0125 - val_loss: 0.0035
# Epoch 11/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0141 - val_loss: 0.0063
# Epoch 12/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0116 - val_loss: 0.0027
# Epoch 13/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0103 - val_loss: 0.0039
# Epoch 14/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0095 - val_loss: 0.0112
# Epoch 15/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0073 - val_loss: 0.0080
# Epoch 16/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0070 - val_loss: 0.0073
# Epoch 17/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0072 - val_loss: 0.0103
# Epoch 18/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0064 - val_loss: 0.0086
# Epoch 19/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0052 - val_loss: 0.0095
# Epoch 20/100
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0056 - val_loss: 0.0072
# Epoch 21/100
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0047 - val_loss: 0.0080
# Epoch 22/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0045 - val_loss: 0.0105
# Epoch 23/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 24/100
# 21/21 [==============================] - 2s 75ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 25/100
# 21/21 [==============================] - 3s 149ms/step - loss: 0.0040 - val_loss: 0.0053
# Epoch 26/100
# 21/21 [==============================] - 3s 138ms/step - loss: 0.0037 - val_loss: 0.0078
# Epoch 27/100
# 21/21 [==============================] - 3s 150ms/step - loss: 0.0036 - val_loss: 0.0049
# Epoch 28/100
# 21/21 [==============================] - 3s 147ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 29/100
# 21/21 [==============================] - 2s 112ms/step - loss: 0.0030 - val_loss: 0.0055
# Epoch 30/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0029 - val_loss: 0.0069
# Epoch 31/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0031 - val_loss: 0.0069
# Epoch 32/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 33/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0029 - val_loss: 0.0041
# Epoch 34/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 35/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 36/100
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0023 - val_loss: 0.0063
# Epoch 37/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 38/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0024 - val_loss: 0.0057
# Epoch 39/100
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 40/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 41/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0018 - val_loss: 0.0046
# Epoch 42/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0019 - val_loss: 0.0067
# Epoch 43/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 44/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 45/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 46/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 47/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 48/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 49/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 50/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 51/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 52/100
# 21/21 [==============================] - 2s 71ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 53/100
# 21/21 [==============================] - 2s 71ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 54/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 55/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 56/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 57/100
# 21/21 [==============================] - 2s 71ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 58/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 59/100
# 21/21 [==============================] - 2s 75ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 60/100
# 21/21 [==============================] - 1s 72ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 61/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 62/100
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 63/100
# 21/21 [==============================] - 2s 71ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 64/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 65/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 66/100
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 67/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0010 - val_loss: 0.0025
# Epoch 68/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 69/100
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 70/100
# 21/21 [==============================] - 2s 71ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 71/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 72/100
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 73/100
# 21/21 [==============================] - 1s 72ms/step - loss: 9.6570e-04 - val_loss: 0.0020
# Epoch 74/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 75/100
# 21/21 [==============================] - 1s 70ms/step - loss: 9.0769e-04 - val_loss: 0.0034
# Epoch 76/100
# 21/21 [==============================] - 1s 72ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 77/100
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0010 - val_loss: 0.0025
# Epoch 78/100
# 21/21 [==============================] - 1s 70ms/step - loss: 8.7962e-04 - val_loss: 0.0031
# Epoch 79/100
# 21/21 [==============================] - 1s 71ms/step - loss: 8.6298e-04 - val_loss: 0.0024
# Epoch 80/100
# 21/21 [==============================] - 1s 72ms/step - loss: 8.2706e-04 - val_loss: 0.0018
# Epoch 81/100
# 21/21 [==============================] - 2s 71ms/step - loss: 9.4962e-04 - val_loss: 0.0033
# Epoch 82/100
# 21/21 [==============================] - 2s 72ms/step - loss: 8.9115e-04 - val_loss: 0.0027
# Epoch 83/100
# 21/21 [==============================] - 2s 92ms/step - loss: 8.7124e-04 - val_loss: 0.0024
# Epoch 84/100
# 21/21 [==============================] - 2s 95ms/step - loss: 8.0589e-04 - val_loss: 0.0018
# Epoch 85/100
# 21/21 [==============================] - 2s 72ms/step - loss: 9.1639e-04 - val_loss: 0.0039
# Epoch 86/100
# 21/21 [==============================] - 2s 72ms/step - loss: 7.5596e-04 - val_loss: 0.0022
# Epoch 87/100
# 21/21 [==============================] - 2s 73ms/step - loss: 8.3756e-04 - val_loss: 0.0020
# Epoch 88/100
# 21/21 [==============================] - 2s 72ms/step - loss: 8.0677e-04 - val_loss: 0.0027
# Epoch 89/100
# 21/21 [==============================] - 2s 73ms/step - loss: 7.8890e-04 - val_loss: 0.0022
# Epoch 90/100
# 21/21 [==============================] - 2s 72ms/step - loss: 8.1624e-04 - val_loss: 0.0022
# Epoch 91/100
# 21/21 [==============================] - 2s 72ms/step - loss: 8.0709e-04 - val_loss: 0.0013
# Epoch 92/100
# 21/21 [==============================] - 2s 73ms/step - loss: 7.9829e-04 - val_loss: 0.0036
# Epoch 93/100
# 21/21 [==============================] - 2s 73ms/step - loss: 7.2788e-04 - val_loss: 0.0025
# Epoch 94/100
# 21/21 [==============================] - 2s 74ms/step - loss: 7.6954e-04 - val_loss: 0.0027
# Epoch 95/100
# 21/21 [==============================] - 2s 73ms/step - loss: 7.3025e-04 - val_loss: 0.0034
# Epoch 96/100
# 21/21 [==============================] - 2s 72ms/step - loss: 7.1396e-04 - val_loss: 0.0015
# Epoch 97/100
# 21/21 [==============================] - 2s 72ms/step - loss: 7.1986e-04 - val_loss: 0.0030
# Epoch 98/100
# 21/21 [==============================] - 2s 72ms/step - loss: 6.6747e-04 - val_loss: 0.0029
# Epoch 99/100
# 21/21 [==============================] - 1s 71ms/step - loss: 6.4240e-04 - val_loss: 0.0016
# Epoch 100/100
# 21/21 [==============================] - 2s 72ms/step - loss: 6.1780e-04 - val_loss: 0.0021
# 0:03:24.155083

# %% [markdown]
# ##### **Do the prediction and check performance metrics**

# %%
# plot loss during training
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(AMAZON_model_dropout, show_shapes=True, show_layer_names=True)

# %%
begin_time = datetime.datetime.now()
train_pred = AMAZON_model_dropout.predict(AMAZON_x_train)
test_pred = AMAZON_model_dropout.predict(AMAZON_x_test)
print(datetime.datetime.now() - begin_time)
# Out:
# 23/23 [==============================] - 1s 17ms/step
# 11/11 [==============================] - 0s 19ms/step
# 0:00:01.382658

# %%
train_pred_inv = sc.inverse_transform(train_pred.copy())
test_pred_inv = sc.inverse_transform(test_pred.copy())
AMAZON_y_train_inv = sc.inverse_transform(np.reshape(AMAZON_y_train,(len(AMAZON_y_train),1)))
AMAZON_y_test_inv = sc.inverse_transform(np.reshape(AMAZON_y_test,(len(AMAZON_y_test),1)))

# %%
# SimpleRNN with Dropout regularization
# evaluation metrics
mse = np.mean(((train_pred_inv - AMAZON_y_train_inv) ** 2))
print("MSE", mse)
print("RMSE", np.sqrt(mse))
# Out:
# MSE 930.6087060206452
# RMSE 30.50587985980154

# %%
mse = np.mean(((test_pred_inv - AMAZON_y_test_inv) ** 2))
print("MSE", mse)
print("RMSE", np.sqrt(mse))
# Out:
# MSE 30563.78106914058
# RMSE 174.82500127024332

# %%
from sklearn.metrics import accuracy_score
# print(test_pred)

for i in range(10):
    print(test_pred_inv[i], AMAZON_y_test_inv[i])
# Out:
# [1686.313] [1902.900024]
# [1690.6465] [1905.390015]
# [1690.866] [1927.680054]
# [1699.2065] [1932.819946]
# [1704.5] [1998.099976]
# [1731.0856] [2002.380005]
# [1753.6448] [2012.709961]
# [1759.1034] [2039.51001]
# [1770.1809] [1994.819946]
# [1757.5538] [1958.310059]

# %%
plt.figure(figsize=(16,8))
plt.plot(AMAZON_y_test_inv, color = 'black', label = 'Test')
plt.plot(test_pred_inv, color = 'green', label = 'pred')
plt.title('SimpleRNN with DROPOUT REGULARIZATION')
plt.legend()
plt.show()

# %% [markdown]
# ## CNN

# %%
from sklearn.model_selection import train_test_split
df = AMZN_df
X = []
Y = []
window_size=100
for i in range(1 , len(df) - window_size -1 , 1):
    first = df.iloc[i,2]
    temp = []
    temp2 = []
    for j in range(window_size):
        temp.append((df.iloc[i + j, 2] - first) / first)
    temp2.append((df.iloc[i + window_size, 2] - first) / first)
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp2).reshape(1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

train_X = train_X.reshape(train_X.shape[0],1,100,1)
test_X = test_X.reshape(test_X.shape[0],1,100,1)

print(len(train_X))
print(len(test_X))
# Out:
# 924
# 231

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
model = tf.keras.Sequential()
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, 100, 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))
#Final layers
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(train_X, train_Y, validation_data=(test_X,test_Y), epochs=40,batch_size=40, verbose=1, shuffle =True)
# Out:
# Epoch 1/40
# 24/24 [==============================] - 2s 33ms/step - loss: 0.0168 - val_loss: 0.0065
# Epoch 2/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0078 - val_loss: 0.0055
# Epoch 3/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 4/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 5/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 6/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 7/40
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 8/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 9/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 10/40
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 11/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 12/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 13/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 14/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 15/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 16/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 17/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 18/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 19/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 20/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 21/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 22/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 23/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 24/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 25/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 26/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 27/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 28/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 29/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 30/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 31/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 32/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 33/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 34/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 35/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 36/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 37/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 38/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 39/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 40/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0021 - val_loss: 0.0015

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
print(model.summary())
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 98, 64)        256
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 49, 64)        0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 47, 128)       24704
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 23, 128)       0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 21, 64)        24640
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 10, 64)        0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 1, 640)           0
#  tributed)
#
#  dense_2 (Dense)             (None, 1, 1)              641
#
# =================================================================
# Total params: 50,241
# Trainable params: 50,241
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.evaluate(test_X, test_Y)
# Out:
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0015
# 0.0014960275730118155

# %%
from sklearn.metrics import explained_variance_score, mean_poisson_deviance, mean_gamma_deviance
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.951923
# R2 Score: 0.951923
# Max Error: 0.121274

# %%
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = AMZN_df.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 0s 14ms/step

# %% [markdown]
# # LSTM

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError
model = tf.keras.Sequential()

# %%
# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mse', metrics=['mae','mse','accuracy'])

print("Amazone: ")
history = model.fit(AMAZON_x_train, AMAZON_y_train, validation_data=(AMAZON_x_test,AMAZON_y_test), epochs=40,batch_size=40, verbose=1, shuffle =True)
# Out:
# Amazone:
# Epoch 1/40
# 18/18 [==============================] - 24s 861ms/step - loss: 0.0161 - mae: 0.0908 - mse: 0.0161 - accuracy: 0.0000e+00 - val_loss: 0.0226 - val_mae: 0.1345 - val_mse: 0.0226 - val_accuracy: 0.0029
# Epoch 2/40
# 18/18 [==============================] - 11s 614ms/step - loss: 0.0036 - mae: 0.0441 - mse: 0.0036 - accuracy: 0.0000e+00 - val_loss: 0.0188 - val_mae: 0.1242 - val_mse: 0.0188 - val_accuracy: 0.0029
# Epoch 3/40
# 18/18 [==============================] - 11s 613ms/step - loss: 0.0021 - mae: 0.0335 - mse: 0.0021 - accuracy: 0.0000e+00 - val_loss: 0.0142 - val_mae: 0.1075 - val_mse: 0.0142 - val_accuracy: 0.0029
# Epoch 4/40
# 18/18 [==============================] - 11s 608ms/step - loss: 0.0018 - mae: 0.0321 - mse: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0041 - val_mae: 0.0523 - val_mse: 0.0041 - val_accuracy: 0.0029
# Epoch 5/40
# 18/18 [==============================] - 13s 739ms/step - loss: 0.0020 - mae: 0.0320 - mse: 0.0020 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_mae: 0.0970 - val_mse: 0.0114 - val_accuracy: 0.0029
# Epoch 6/40
# 18/18 [==============================] - 11s 619ms/step - loss: 0.0016 - mae: 0.0295 - mse: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_mae: 0.0647 - val_mse: 0.0059 - val_accuracy: 0.0029
# Epoch 7/40
# 18/18 [==============================] - 11s 608ms/step - loss: 0.0018 - mae: 0.0307 - mse: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_mae: 0.0698 - val_mse: 0.0066 - val_accuracy: 0.0029
# Epoch 8/40
# 18/18 [==============================] - 11s 614ms/step - loss: 0.0015 - mae: 0.0280 - mse: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0038 - val_mae: 0.0505 - val_mse: 0.0038 - val_accuracy: 0.0029
# Epoch 9/40
# 18/18 [==============================] - 11s 612ms/step - loss: 0.0015 - mae: 0.0284 - mse: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_mae: 0.0757 - val_mse: 0.0074 - val_accuracy: 0.0029
# Epoch 10/40
# 18/18 [==============================] - 11s 611ms/step - loss: 0.0016 - mae: 0.0290 - mse: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0150 - val_mae: 0.1162 - val_mse: 0.0150 - val_accuracy: 0.0029
# Epoch 11/40
# 18/18 [==============================] - 11s 611ms/step - loss: 0.0018 - mae: 0.0294 - mse: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_mae: 0.0322 - val_mse: 0.0016 - val_accuracy: 0.0029
# Epoch 12/40
# 18/18 [==============================] - 11s 619ms/step - loss: 0.0014 - mae: 0.0278 - mse: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_mae: 0.0824 - val_mse: 0.0082 - val_accuracy: 0.0029
# Epoch 13/40
# 18/18 [==============================] - 11s 618ms/step - loss: 0.0013 - mae: 0.0271 - mse: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0151 - val_mae: 0.1170 - val_mse: 0.0151 - val_accuracy: 0.0029
# Epoch 14/40
# 18/18 [==============================] - 11s 619ms/step - loss: 0.0014 - mae: 0.0273 - mse: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0092 - val_mae: 0.0885 - val_mse: 0.0092 - val_accuracy: 0.0029
# Epoch 15/40
# 18/18 [==============================] - 11s 621ms/step - loss: 0.0012 - mae: 0.0255 - mse: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0057 - val_mae: 0.0670 - val_mse: 0.0057 - val_accuracy: 0.0029
# Epoch 16/40
# 18/18 [==============================] - 13s 707ms/step - loss: 0.0015 - mae: 0.0266 - mse: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0038 - val_mae: 0.0519 - val_mse: 0.0038 - val_accuracy: 0.0029
# Epoch 17/40
# 18/18 [==============================] - 13s 725ms/step - loss: 0.0013 - mae: 0.0260 - mse: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0157 - val_mae: 0.1202 - val_mse: 0.0157 - val_accuracy: 0.0029
# Epoch 18/40
# 18/18 [==============================] - 11s 618ms/step - loss: 0.0013 - mae: 0.0257 - mse: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_mae: 0.0709 - val_mse: 0.0062 - val_accuracy: 0.0029
# Epoch 19/40
# 18/18 [==============================] - 11s 621ms/step - loss: 0.0011 - mae: 0.0244 - mse: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0052 - val_mae: 0.0640 - val_mse: 0.0052 - val_accuracy: 0.0029
# Epoch 20/40
# 18/18 [==============================] - 15s 830ms/step - loss: 0.0013 - mae: 0.0251 - mse: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_mae: 0.0740 - val_mse: 0.0066 - val_accuracy: 0.0029
# Epoch 21/40
# 18/18 [==============================] - 16s 900ms/step - loss: 0.0011 - mae: 0.0239 - mse: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0041 - val_mae: 0.0556 - val_mse: 0.0041 - val_accuracy: 0.0029
# Epoch 22/40
# 18/18 [==============================] - 16s 900ms/step - loss: 0.0011 - mae: 0.0248 - mse: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0035 - val_mae: 0.0505 - val_mse: 0.0035 - val_accuracy: 0.0029
# Epoch 23/40
# 18/18 [==============================] - 12s 631ms/step - loss: 0.0012 - mae: 0.0250 - mse: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_mae: 0.0772 - val_mse: 0.0071 - val_accuracy: 0.0029
# Epoch 24/40
# 18/18 [==============================] - 11s 624ms/step - loss: 0.0012 - mae: 0.0239 - mse: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0024 - val_mae: 0.0395 - val_mse: 0.0024 - val_accuracy: 0.0029
# Epoch 25/40
# 18/18 [==============================] - 12s 668ms/step - loss: 0.0012 - mae: 0.0249 - mse: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_mae: 0.0779 - val_mse: 0.0072 - val_accuracy: 0.0029
# Epoch 26/40
# 18/18 [==============================] - 11s 619ms/step - loss: 0.0011 - mae: 0.0241 - mse: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0013 - val_mae: 0.0277 - val_mse: 0.0013 - val_accuracy: 0.0029
# Epoch 27/40
# 18/18 [==============================] - 11s 610ms/step - loss: 0.0010 - mae: 0.0229 - mse: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_mae: 0.0301 - val_mse: 0.0015 - val_accuracy: 0.0029
# Epoch 28/40
# 18/18 [==============================] - 11s 624ms/step - loss: 0.0012 - mae: 0.0240 - mse: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0052 - val_mae: 0.0640 - val_mse: 0.0052 - val_accuracy: 0.0029
# Epoch 29/40
# 18/18 [==============================] - 11s 621ms/step - loss: 0.0011 - mae: 0.0232 - mse: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0035 - val_mae: 0.0507 - val_mse: 0.0035 - val_accuracy: 0.0029
# Epoch 30/40
# 18/18 [==============================] - 11s 617ms/step - loss: 0.0010 - mae: 0.0235 - mse: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0013 - val_mae: 0.0291 - val_mse: 0.0013 - val_accuracy: 0.0029
# Epoch 31/40
# 18/18 [==============================] - 11s 626ms/step - loss: 0.0011 - mae: 0.0243 - mse: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0036 - val_mae: 0.0521 - val_mse: 0.0036 - val_accuracy: 0.0029
# Epoch 32/40
# 18/18 [==============================] - 11s 629ms/step - loss: 9.1556e-04 - mae: 0.0232 - mse: 9.1556e-04 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_mae: 0.0890 - val_mse: 0.0090 - val_accuracy: 0.0029
# Epoch 33/40
# 18/18 [==============================] - 11s 619ms/step - loss: 9.4913e-04 - mae: 0.0221 - mse: 9.4913e-04 - accuracy: 0.0000e+00 - val_loss: 0.0010 - val_mae: 0.0238 - val_mse: 0.0010 - val_accuracy: 0.0029
# Epoch 34/40
# 18/18 [==============================] - 11s 628ms/step - loss: 0.0010 - mae: 0.0231 - mse: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_mae: 0.0340 - val_mse: 0.0018 - val_accuracy: 0.0029
# Epoch 35/40
# 18/18 [==============================] - 12s 659ms/step - loss: 9.4902e-04 - mae: 0.0227 - mse: 9.4902e-04 - accuracy: 0.0000e+00 - val_loss: 0.0034 - val_mae: 0.0505 - val_mse: 0.0034 - val_accuracy: 0.0029
# Epoch 36/40
# 18/18 [==============================] - 11s 620ms/step - loss: 9.9960e-04 - mae: 0.0231 - mse: 9.9960e-04 - accuracy: 0.0000e+00 - val_loss: 0.0023 - val_mae: 0.0394 - val_mse: 0.0023 - val_accuracy: 0.0029
# Epoch 37/40
# 18/18 [==============================] - 11s 627ms/step - loss: 0.0010 - mae: 0.0231 - mse: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0038 - val_mae: 0.0535 - val_mse: 0.0038 - val_accuracy: 0.0029
# Epoch 38/40
# 18/18 [==============================] - 11s 619ms/step - loss: 0.0010 - mae: 0.0237 - mse: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_mae: 0.1061 - val_mse: 0.0123 - val_accuracy: 0.0029
# Epoch 39/40
# 18/18 [==============================] - 11s 626ms/step - loss: 9.8295e-04 - mae: 0.0236 - mse: 9.8295e-04 - accuracy: 0.0000e+00 - val_loss: 0.0045 - val_mae: 0.0594 - val_mse: 0.0045 - val_accuracy: 0.0029
# Epoch 40/40
# 18/18 [==============================] - 12s 667ms/step - loss: 0.0011 - mae: 0.0245 - mse: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_mae: 0.0313 - val_mse: 0.0015 - val_accuracy: 0.0029

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# After the model has been constructed, we'll summarise it
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 100, 200)         81600
#  l)
#
#  dropout_3 (Dropout)         (None, 100, 200)          0
#
#  bidirectional_1 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_3 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 322,601
# Trainable params: 322,601
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.evaluate(AMAZON_x_test, AMAZON_y_test)
# Out:
# 11/11 [==============================] - 1s 106ms/step - loss: 0.0015 - mae: 0.0313 - mse: 0.0015 - accuracy: 0.0029
# [0.0014758341712877154,
#  0.03130890429019928,
#  0.0014758341712877154,
#  0.0029411765281111]

# %%
from sklearn.metrics import explained_variance_score, mean_poisson_deviance, mean_gamma_deviance
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(AMAZON_x_test, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(AMAZON_y_test.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(AMAZON_y_test.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(AMAZON_y_test.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.820478
# R2 Score: 0.820478
# Max Error: 0.107748

# %%
predicted  = model.predict(AMAZON_x_test)
test_label = AMAZON_y_test.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(AMAZON_x_train)
for j in range(len_t , len_t + len(AMAZON_x_test)):
    temp = AMZN_df.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
# Out:
# 11/11 [==============================] - 2s 188ms/step
